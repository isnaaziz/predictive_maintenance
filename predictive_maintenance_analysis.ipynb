# %% [markdown]
# # Proyek Mini: Prediksi Kegagalan Perangkat IoT (Predictive Maintenance)
# ### Mata Kuliah: Matematika Statistika
#
# Proyek ini telah dimodularisasi untuk memudahkan penjelasan dan pemeliharaan. Kode dibagi menjadi beberapa modul:
# 1. `data_loader`: Mengambil dan menyiapkan data.
# 2. `eda`: Analisis data deskriptif dan visualisasi.
# 3. `stats_models`: Pemodelan Regresi dan Distribusi Probabilitas.
# 4. `anomaly_detection`: Deteksi anomali menggunakan Z-score.

# %%
from src.data_loader import load_maintenance_data
from src.eda import perform_eda
from src.stats_models import analyze_regression, analyze_probability
from src.anomaly_detection import detect_anomalies

# Matplotlib inline untuk notebook
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data
# Mengambil dataset AI4I 2020 dari UCI Repository.

# %%
df = load_maintenance_data()
df.head()

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
# Melihat statistik deskriptif dan distribusi variabel kunci.

# %%
perform_eda(df)

# %% [markdown]
# ## 3. Regresi & Korelasi
# Menganalisis hubungan antara beban kerja (Torque) dan suhu proses.

# %%
analyze_regression(df)

# %% [markdown]
# ## 4. Distribusi Probabilitas (Normal & Poisson)
# Menghitung peluang kejadian kritis dan kegagalan.

# %%
analyze_probability(df)

# %% [markdown]
# ## 5. Threshold Kegagalan (Z-Score)
# Mendeteksi anomali pada sensor kecepatan rotasi.

# %%
anomalies = detect_anomalies(df)
anomalies.head()
